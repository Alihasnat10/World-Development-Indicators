# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Data_Extract_From_World_Development_Indicators.xlsx')

# %%
df.head(10)
# Out:
#                                        Country Name Country Code  \
# 0                                          Pakistan          PAK
# 1                                          Pakistan          PAK
# 2                                          Pakistan          PAK
# 3                                          Pakistan          PAK
# 4                                               NaN          NaN
# 5                                               NaN          NaN
# 6                                               NaN          NaN
# 7  Data from database: World Development Indicators          NaN
# 8                          Last Updated: 07/01/2020          NaN
#
#                                          Series Name           Series Code  \
# 0  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.NE.ZS
# 1                              GDP growth (annual %)     NY.GDP.MKTP.KD.ZG
# 2  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# ...

# %%
df.shape
# Out:
# (9, 54)

# %%
df.describe()
# Out:
#        1971 [YR1971]  1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  \
# count       4.000000       4.000000       4.000000       4.000000
# mean        1.317440       1.466167       2.940274       2.019502
# std         1.283982       1.171944       2.996760       1.525222
# min         0.009376       0.180563      -0.062662       0.044948
# 25%         0.353623       0.655195       1.484334       1.263737
# 50%         1.279186       1.481703       2.379747       2.246434
# 75%         2.243002       2.292675       3.835686       3.002199
# max         2.702010       2.720700       7.064264       3.540192
#
#        1975 [YR1975]  1976 [YR1976]  1977 [YR1977]  1978 [YR1978]  \
# count       4.000000       4.000000       4.000000       4.000000
# mean        2.258897       2.523325       2.246785       3.879117
# std         1.701392       2.127616       1.657969       3.252987
# min         0.222606       0.062428       0.100642       0.181193
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#   Country Name Country Code  \
# 0     Pakistan          PAK
# 1     Pakistan          PAK
# 2     Pakistan          PAK
# 3     Pakistan          PAK
#
#                                          Series Name           Series Code  \
# 0  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.NE.ZS
# 1                              GDP growth (annual %)     NY.GDP.MKTP.KD.ZG
# 2  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 3                       Population growth (annual %)           SP.POP.GROW
#
#   1970 [YR1970]  1971 [YR1971]  1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  \
# 0            ..       2.090000       2.150000       2.000000       1.670000
# 1       11.3535       0.468373       0.813406       7.064264       3.540192
# 2      0.229369       0.009376       0.180563      -0.062662       0.044948
# 3       2.69131       2.702010       2.720700       2.759494       2.822868
#
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1970 [YR1970]', '1971 [YR1971]', '1972 [YR1972]', '1973 [YR1973]',
#        '1974 [YR1974]', '1975 [YR1975]', '1976 [YR1976]', '1977 [YR1977]',
#        '1978 [YR1978]', '1979 [YR1979]', '1980 [YR1980]', '1981 [YR1981]',
#        '1982 [YR1982]', '1983 [YR1983]', '1984 [YR1984]', '1985 [YR1985]',
#        '1986 [YR1986]', '1987 [YR1987]', '1988 [YR1988]', '1989 [YR1989]',
#        '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]', '1993 [YR1993]',
#        '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
# ...

# %%
nan_columns = df[['1970 [YR1970]', '2012 [YR2012]', '2016 [YR2016]', '2017 [YR2017]', '2019 [YR2019]']]
for col in nan_columns:
    df[col].replace('..', np.nan, inplace = True)
    print(df[col].fillna(value = pd.to_numeric(df[col]).mean()))
# Out:
# 0     4.758048
# 1    11.353462
# 2     0.229369
# 3     2.691313
# Name: 1970 [YR1970], dtype: float64
# 0    2.005524
# 1    3.507033
# 2    0.382827
# 3    2.126712
# Name: 2012 [YR2012], dtype: float64
# 0    2.845166
# 1    5.526736
# 2    0.924442
# 3    2.084321
# Name: 2016 [YR2016], dtype: float64
# 0    2.816266
# 1    5.554277
# 2    0.819523
# 3    2.074997
# Name: 2017 [YR2017], dtype: float64
# 0    1.271750
# 1    0.988829
# 2    0.797205
# 3    2.029215
# Name: 2019 [YR2019], dtype: float64

# %%
df.head()
# Out:
#   Country Name Country Code  \
# 0     Pakistan          PAK
# 1     Pakistan          PAK
# 2     Pakistan          PAK
# 3     Pakistan          PAK
#
#                                          Series Name           Series Code  \
# 0  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.NE.ZS
# 1                              GDP growth (annual %)     NY.GDP.MKTP.KD.ZG
# 2  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 3                       Population growth (annual %)           SP.POP.GROW
#
#    1970 [YR1970]  1971 [YR1971]  1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  \
# 0            NaN       2.090000       2.150000       2.000000       1.670000
# 1      11.353462       0.468373       0.813406       7.064264       3.540192
# 2       0.229369       0.009376       0.180563      -0.062662       0.044948
# 3       2.691313       2.702010       2.720700       2.759494       2.822868
#
# ...
